# %% [markdown]
# <a href="https://colab.research.google.com/github/MingiPark/Cat_Dog_Classification/blob/main/parkmingi_cat_dog_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
import os
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.8)
# Requirement already satisfied: slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (0.0.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-80045cda-a628-48c6-a48d-958c79e462ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80045cda-a628-48c6-a48d-958c79e462ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"mingipark","key":"27d53b7c76dffad50151922d56bc46cf"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# Downloading test1.zip to /content
#  94% 256M/271M [00:06<00:00, 45.2MB/s]
# 100% 271M/271M [00:06<00:00, 43.9MB/s]
# Downloading train.zip to /content
#  98% 532M/543M [00:10<00:00, 67.6MB/s]
# 100% 543M/543M [00:10<00:00, 55.7MB/s]
# Downloading sampleSubmission.csv to /content
#   0% 0.00/86.8k [00:00<?, ?B/s]
# 100% 86.8k/86.8k [00:00<00:00, 27.8MB/s]

# %%
print(os.listdir("../content/dataset"))
# Out:
# ['sampleSubmission.csv', 'train', 'test1']

# %% [markdown]
# Define Constants

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# Prepare Training Data

# %%
train_dir = "../content/dataset/train"
filenames = os.listdir(train_dir)
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %% [markdown]
# Build Model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# Early Stop : To prevent overfitting(stop the learning after 10 epoches and val_loss value not decreased)

# %%
earlystop = EarlyStopping(patience=15)

# %% [markdown]
# Learning Rate Reduction : reduce the learning rate when the accuaracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# Prepare Data

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'}) 

train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %% [markdown]
# Training Generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    train_dir, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %% [markdown]
# Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    train_dir, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# Example

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    train_dir, 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)

plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %% [markdown]
# Fit Model

# %%
epochs=2 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.8868WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2682 - accuracy: 0.8868 - val_loss: 0.3087 - val_accuracy: 0.8885
# Epoch 2/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.8850WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2716 - accuracy: 0.8850 - val_loss: 0.2343 - val_accuracy: 0.9139
# Epoch 3/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2659 - accuracy: 0.8895WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2659 - accuracy: 0.8895 - val_loss: 0.2410 - val_accuracy: 0.9117
# Epoch 4/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2701 - accuracy: 0.8871WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2701 - accuracy: 0.8871 - val_loss: 0.2322 - val_accuracy: 0.9195
# Epoch 5/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8878WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2693 - accuracy: 0.8878 - val_loss: 0.3245 - val_accuracy: 0.8859
# Epoch 6/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.8933WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2604 - accuracy: 0.8933 - val_loss: 0.2501 - val_accuracy: 0.9035
# Epoch 7/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.8904WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2654 - accuracy: 0.8904 - val_loss: 0.3751 - val_accuracy: 0.8571
# Epoch 8/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.8921WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2601 - accuracy: 0.8921 - val_loss: 0.1976 - val_accuracy: 0.9257
# Epoch 9/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2651 - accuracy: 0.8900WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 153s 115ms/step - loss: 0.2651 - accuracy: 0.8900 - val_loss: 0.2359 - val_accuracy: 0.9157
# Epoch 10/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.
ARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2522 - accuracy: 0.8969 - val_loss: 0.2348 - val_accuracy: 0.9293
# Epoch 29/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2464 - accuracy: 0.8990WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2464 - accuracy: 0.8990 - val_loss: 0.3414 - val_accuracy: 0.8420
# Epoch 30/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2406 - accuracy: 0.9006WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 148s 111ms/step - loss: 0.2406 - accuracy: 0.9006 - val_loss: 0.2226 - val_accuracy: 0.9133
# Epoch 31/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9014WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 149s 112ms/step - loss: 0.2379 - accuracy: 0.9014 - val_loss: 0.2487 - val_accuracy: 0.9099
# Epoch 32/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9017WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 148s 111ms/step - loss: 0.2430 - accuracy: 0.9017 - val_loss: 0.2231 - val_accuracy: 0.9165
# Epoch 33/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.8984WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 147s 110ms/step - loss: 0.2482 - accuracy: 0.8984 - val_loss: 0.2186 - val_accuracy: 0.9129
# Epoch 34/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.9025WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 147s 110ms/step - loss: 0.2416 - accuracy: 0.9025 - val_loss: 0.2060 - val_accuracy: 0.9187
# Epoch 35/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2389 - accuracy: 0.9032WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 146s 110ms/step - loss: 0.2389 - accuracy: 0.9032 - val_loss: 0.2838 - val_accuracy: 0.8875
# Epoch 36/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.8979WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 146s 110ms/step - loss: 0.2493 - accuracy: 0.8979 - val_loss: 0.2547 - val_accuracy: 0.8961
# Epoch 37/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9030WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 146s 110ms/step - loss: 0.2337 - accuracy: 0.9030 - val_loss: 0.1869 - val_accuracy: 0.9349
# Epoch 38/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2421 - accuracy: 0.9003WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 146s 110ms/step - loss: 0.2421 - accuracy: 0.9003 - val_loss: 0.2157 - val_accuracy: 0.9157
# Epoch 39/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2421 - accuracy: 0.9007WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 146s 110ms/step - loss: 0.2421 - accuracy: 0.9007 - val_loss: 0.2389 - val_accuracy: 0.9057
# Epoch 40/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9019WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 146s 110ms/step - loss: 0.2447 - accuracy: 0.9019 - val_loss: 0.2087 - val_accuracy: 0.9211
# Epoch 41/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2370 - accuracy: 0.9016WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 146s 110ms/step - loss: 0.2370 - accuracy: 0.9016 - val_loss: 0.1843 - val_accuracy: 0.9317
# Epoch 42/50
# 1333/1333 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9045WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 1333/1333 [==============================] - 145s 109ms/step - loss: 0.2348 - accuracy: 0.9045 - val_loss: 0.2416 - val_accuracy: 0.9079

# %% [markdown]
# Save Model

# %%
model.save_weights("model.h5")

# %% [markdown]
# Virtualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Prepare Testing Data

# %%
test_dir = "../content/dataset/test1"
test_filenames = os.listdir(test_dir)
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %% [markdown]
# Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    test_dir, 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %% [markdown]
# Predict

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
test_df['category'] = np.argmax(predict, axis=-1)
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })
test_df['category'].value_counts().plot.bar()
# Out:
# WARNING:tensorflow:From <ipython-input-88-29c3449952ba>:1: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %% [markdown]
# Show predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img(test_dir + "/" + filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()

# %% [markdown]
# Submission

# %%
submission_df = test_df.copy()
submission_df['id'] = submission_df['filename'].str.split('.').str[0]
submission_df['label'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
submission_df.to_csv('submission.csv', index=False)
